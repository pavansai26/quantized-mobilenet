# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
import math
import os

# %%
from keras.models import model_from_json
from keras.preprocessing import image
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.utils import np_utils
import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D
from keras.layers import Flatten, MaxPool2D
from keras.layers import  Dropout, ReLU
from keras.layers import DepthwiseConv2D

#from IPython.display import SVG
#from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np
import cv2
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.keras.preprocessing.image import *
import tensorflow as tf

# %%
import cv2

# %%
img=load_img('C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/krishna.jpg')

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,\
 width_shift_range=0.2,
 height_shift_range=0.2,
 channel_shift_range=0.1,
 vertical_flip=True,
 rotation_range=30)

# %%
y=img_to_array(img)
new=cv2.resize(y,(50,50))
x=new.reshape((1,)+new.shape)

# %%
i=0
for batch in train_datagen.flow(x,batch_size=1,save_to_dir='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata/krishna',
save_prefix='krishna',save_format='jpg'):
    i+=1
    if i>300:
        break

# %%
def trainingdata():
    training_data = []
    file='C:/Users/lenovo/Downloads/challenges-in-representation-learning-facial-expression-recognition-challenge/daaata'
    categories=['pavan','balaji','krishna','shakeel','abhilash']
    for category in categories:
        path = os.path.join(file,category)
        class_num = categories.index(category)
        for img in (os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (50,50))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
    return training_data

# %%
trainingdata()
# Out:
# [[array([[187, 188, 189, ..., 216, 218, 218],
#          [204, 200, 193, ..., 216, 218, 218],
#          [202, 202, 201, ..., 217, 218, 218],
#          ...,
#          [159, 156, 134, ..., 218, 220, 219],
#          [ 84, 143, 169, ..., 219, 218, 218],
#          [110, 147, 164, ..., 218, 218, 218]], dtype=uint8), 0],
#  [array([[203, 206, 198, ..., 143, 149, 147],
#          [193, 196, 197, ..., 152, 152, 153],
#          [190, 191, 195, ..., 155, 143, 142],
#          ...,
#          [178, 179, 180, ..., 151, 159, 164],
#          [181, 181, 182, ..., 160, 160, 154],
#          [181, 181, 182, ..., 176, 165, 159]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 231, 229, 229],
#          [232, 232, 232, ..., 231, 230, 230],
#          [232, 232, 232, ..., 231, 231, 231],
#          ...,
#          [158, 157, 156, ..., 151, 153, 152],
#          [152, 151, 150, ..., 149, 153, 158],
#          [124, 122, 121, ..., 140, 118, 124]], dtype=uint8), 0],
#  [array([[ 19,  13,   0, ...,  61,  83,  83],
#          [ 17,   8,   0, ...,  66,  83,  83],
#          [ 11,  11,  15, ...,  73,  83,  83],
#          ...,
#          [199, 200, 202, ..., 207, 236, 236],
#          [195, 197, 199, ..., 224, 200, 201],
#          [195, 197, 199, ..., 220, 231, 232]], dtype=uint8), 0],
#  [array([[222, 222, 222, ..., 168, 201, 212],
#          [218, 218, 217, ..., 167, 190, 209],
#          [210, 210, 210, ..., 167, 172, 193],
#          ...,
#          [ 76,  76,  76, ...,  16,  35,  40],
#          [ 75,  75,  75, ...,  12,  35,  37],
#          [ 75,  75,  75, ...,  12,  35,  37]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 231, 231, 231],
#          [230, 230, 230, ..., 231, 231, 231],
#          [230, 230, 230, ..., 231, 231, 231],
#          ...,
#          [240, 243, 247, ...,  68,  67,  76],
#          [252, 246, 247, ...,  78,  69,  70],
#          [249, 242, 243, ...,  78,  69,  70]], dtype=uint8), 0],
#  [array([[165, 164, 163, ..., 216, 217, 217],
#          [167, 166, 164, ..., 215, 217, 217],
#          [167, 167, 166, ..., 214, 217, 217],
#          ...,
#          [ 80,  82,  77, ..., 213, 216, 216],
#          [ 82,  77,  85, ..., 223, 217, 217],
#          [ 81,  76,  84, ..., 200, 217, 217]], dtype=uint8), 0],
#  [array([[206, 205, 204, ..., 163,  25,  15],
#          [197, 197, 198, ..., 124,  18,  14],
#          [205, 205, 204, ...,  37,   7,   9],
#          ...,
#          [166, 166, 165, ..., 209, 212, 211],
#          [166, 165, 165, ..., 216, 216, 216],
#          [166, 165, 165, ..., 218, 220, 220]], dtype=uint8), 0],
#  [array([[231, 231, 231, ..., 178, 176, 176],
#          [227, 227, 227, ..., 179, 176, 176],
#          [221, 221, 221, ..., 179, 176, 176],
#          ...,
#          [205, 205, 205, ..., 135, 141, 155],
#          [200, 200, 200, ..., 138, 155, 155],
#          [200, 200, 200, ..., 153, 163, 162]], dtype=uint8), 0],
#  [array([[212, 210, 207, ..., 123, 138, 130],
#          [195, 204, 212, ..., 125, 136, 122],
#          [193, 197, 204, ..., 131, 130, 118],
#          ...,
#          [168, 169, 170, ..., 222, 223, 223],
#          [169, 169, 171, ..., 187, 206, 224],
#          [169, 169, 171, ..., 190, 191, 209]], dtype=uint8), 0],
#  [array([[175, 173, 169, ..., 205, 208, 209],
#          [176, 176, 175, ..., 206, 208, 209],
#          [186, 187, 187, ..., 206, 209, 209],
#          ...,
#          [ 68,  50,  25, ...,  40,   9,  11],
#          [ 65,  40,  34, ...,  47,  14,  11],
#          [ 57,  34,  31, ..., 148,  16,  12]], dtype=uint8), 0],
#  [array([[234, 234, 233, ..., 230, 230, 230],
#          [234, 234, 234, ..., 230, 231, 231],
#          [235, 235, 234, ..., 230, 231, 231],
#          ...,
#          [ 90,  65,  81, ..., 235, 230, 230],
#          [ 80,  72,  81, ..., 238, 220, 233],
#          [ 80,  72,  81, ..., 187, 205, 218]], dtype=uint8), 0],
#  [array([[231, 231, 231, ..., 233, 232, 232],
#          [231, 231, 231, ..., 233, 232, 232],
#          [231, 231, 231, ..., 233, 232, 232],
#          ...,
#          [ 96,  97,  99, ...,  70,  82,  88],
#          [149, 148, 146, ...,  69,  82,  88],
#          [117, 116, 114, ...,  69,  78,  83]], dtype=uint8), 0],
#  [array([[230, 230, 231, ..., 231, 231, 231],
#          [231, 231, 231, ..., 231, 231, 231],
#          [232, 232, 231, ..., 231, 231, 231],
#          ...,
#          [ 49,  42,  51, ..., 241, 242, 242],
#          [ 56,  50,  49, ..., 244, 244, 244],
#          [ 62,  55,  52, ..., 244, 244, 244]], dtype=uint8), 0],
#  [array([[166, 164, 166, ..., 233, 233, 233],
#          [166, 165, 166, ..., 232, 233, 233],
#          [166, 165, 166, ..., 232, 233, 233],
#          ...,
#          [200, 199, 198, ...,  31,  39,  94],
#          [191, 191, 190, ...,  34,  43,  67],
#          [190, 190, 189, ...,  12,  20,  43]], dtype=uint8), 0],
#  [array([[168, 176, 180, ..., 229, 231, 231],
#          [172, 177, 182, ..., 229, 231, 231],
#          [177, 179, 184, ..., 224, 225, 225],
#          ...,
#          [ 80,  67,  46, ...,  38,  75,  75],
#          [ 80,  68,  48, ...,  41,  73,  73],
#          [ 80,  68,  48, ...,  41,  73,  73]], dtype=uint8), 0],
#  [array([[170, 170, 172, ..., 233, 233, 233],
#          [170, 170, 172, ..., 233, 233, 233],
#          [170, 170, 172, ..., 233, 233, 233],
#          ...,
#          [169, 154, 151, ..., 213, 203, 203],
#          [163, 158, 157, ..., 201, 202, 202],
#          [163, 159, 159, ..., 200, 200, 200]], dtype=uint8), 0],
#  [array([[221, 215, 207, ..., 199, 199, 200],
#          [187, 203, 219, ..., 199, 201, 202],
#          [164, 174, 190, ..., 200, 204, 204],
#          ...,
#          [ 82,  77,  78, ..., 113, 208, 209],
#          [ 83,  88,  71, ..., 125, 204, 218],
#          [ 78,  83,  67, ...,  95, 204, 218]], dtype=uint8), 0],
#  [array([[ 85,  74,  75, ...,  80,  82,  80],
#          [150, 153, 168, ...,  93,  77,  79],
#          [168, 186, 195, ...,  86,  89,  94],
#          ...,
#          [229, 229, 229, ..., 231, 231, 231],
#          [230, 230, 230, ..., 230, 231, 231],
#          [230, 230, 230, ..., 230, 231, 231]], dtype=uint8), 0],
#  [array([[ 84, 104,  86, ..., 207, 198, 198],
#          [ 82,  93,  64, ..., 193, 206, 206],
#          [ 90,  95,  65, ..., 206, 206, 206],
#          ...,
#          [190, 194, 200, ..., 171, 169, 167],
#          [200, 202, 205, ..., 171, 170, 169],
#          [204, 206, 209, ..., 171, 170, 169]], dtype=uint8), 0],
#  [array([[148,  73,  86, ...,  78,  82,  80],
#          [169,  80,  96, ...,  79,  68,  65],
#          [171,  88, 100, ...,  55,  46,  45],
#          ...,
#          [158, 163, 162, ..., 169, 170, 169],
#          [158, 161, 165, ..., 174, 171, 171],
#          [175, 179, 183, ..., 174, 171, 171]], dtype=uint8), 0],
#  [array([[176, 175, 173, ..., 182, 183, 183],
#          [178, 178, 178, ..., 182, 184, 184],
#          [177, 178, 179, ..., 182, 185, 185],
#          ...,
#          [134, 101, 127, ..., 130,  18,  18],
#          [118, 122, 127, ...,  87,   6,  11],
#          [118, 122, 127, ...,  51,   6,  11]], dtype=uint8), 0],
#  [array([[191, 191, 191, ..., 177, 180, 180],
#          [160, 163, 169, ..., 179, 179, 179],
#          [156, 157, 158, ..., 180, 178, 178],
#          ...,
#          [117, 128,  83, ...,  48,  61,  57],
#          [175,  83,  94, ...,  71,  82,  82],
#          [166,  76,  91, ...,  80,  82,  82]], dtype=uint8), 0],
#  [array([[220, 220, 221, ..., 155, 151, 121],
#          [223, 222, 222, ..., 127, 136, 125],
#          [225, 224, 223, ..., 122, 131, 144],
#          ...,
#          [222, 222, 221, ..., 173, 179, 179],
#          [222, 222, 222, ..., 169, 170, 170],
#          [222, 222, 222, ..., 169, 170, 170]], dtype=uint8), 0],
#  [array([[221, 220, 219, ..., 168, 166, 154],
#          [222, 222, 221, ..., 171, 159, 140],
#          [223, 223, 223, ..., 173, 156, 123],
#          ...,
#          [224, 223, 223, ..., 168, 171, 171],
#          [224, 222, 220, ..., 172, 168, 168],
#          [224, 222, 220, ..., 167, 168, 168]], dtype=uint8), 0],
#  [array([[195, 205, 215, ..., 155, 146, 155],
#          [201, 196, 194, ..., 149, 147, 154],
#          [216, 205, 195, ..., 145, 148, 149],
#          ...,
#          [166, 166, 169, ..., 223, 218, 218],
#          [167, 168, 170, ..., 224, 222, 222],
#          [167, 168, 170, ..., 214, 222, 222]], dtype=uint8), 0],
#  [array([[223, 222, 220, ..., 169, 171, 171],
#          [224, 222, 219, ..., 171, 173, 173],
#          [225, 222, 217, ..., 174, 175, 175],
#          ...,
#          [206, 209, 208, ..., 118, 123, 119],
#          [207, 207, 207, ..., 113, 128, 122],
#          [207, 207, 207, ..., 108, 128, 122]], dtype=uint8), 0],
#  [array([[ 80,  77,  79, ...,  69,  73,  74],
#          [ 80,  77,  79, ...,  75,  73,  74],
#          [ 80,  78,  79, ...,  81,  73,  74],
#          ...,
#          [169, 170, 172, ..., 189, 192, 193],
#          [169, 169, 169, ..., 193, 197, 197],
#          [169, 169, 169, ..., 195, 199, 200]], dtype=uint8), 0],
#  [array([[195, 197, 198, ..., 224, 211, 209],
#          [196, 198, 198, ..., 191, 178, 176],
#          [198, 198, 198, ..., 166, 163, 162],
#          ...,
#          [ 29,  19,   9, ...,  19,  32,  35],
#          [ 27,  23,  11, ...,  14,  21,  34],
#          [ 29,  23,  11, ...,  17,  21,  34]], dtype=uint8), 0],
#  [array([[121, 122, 121, ...,  63,  63,  58],
#          [119, 121, 121, ...,  57,  52,  53],
#          [146, 148, 148, ...,  84,  65,  69],
#          ...,
#          [231, 231, 231, ..., 229, 228, 228],
#          [231, 231, 231, ..., 227, 229, 229],
#          [231, 231, 231, ..., 227, 229, 229]], dtype=uint8), 0],
#  [array([[173, 171, 168, ..., 214, 216, 216],
#          [176, 173, 171, ..., 214, 216, 216],
#          [178, 176, 174, ..., 215, 216, 216],
#          ...,
#          [131, 108, 118, ..., 220, 218, 218],
#          [119, 125, 127, ..., 215, 215, 215],
#          [118, 124, 126, ..., 214, 215, 215]], dtype=uint8), 0],
#  [array([[166, 174, 181, ..., 213, 214, 212],
#          [166, 173, 180, ..., 211, 212, 211],
#          [166, 172, 178, ..., 207, 208, 206],
#          ...,
#          [204, 201, 198, ..., 158, 150, 155],
#          [196, 198, 201, ..., 142, 157, 176],
#          [203, 204, 206, ..., 141, 157, 176]], dtype=uint8), 0],
#  [array([[138, 109,  84, ...,  40,  54,  70],
#          [ 85, 127,  85, ...,  50,  32,  60],
#          [ 86, 149,  69, ...,  24,  55,  90],
#          ...,
#          [234, 234, 234, ..., 173, 171, 171],
#          [233, 232, 232, ..., 174, 170, 170],
#          [233, 232, 232, ..., 174, 170, 170]], dtype=uint8), 0],
#  [array([[220, 220, 220, ..., 186, 172, 170],
#          [220, 221, 221, ..., 185, 173, 171],
#          [221, 221, 221, ..., 187, 179, 176],
#          ...,
#          [ 50,  34,  35, ..., 127, 139, 151],
#          [ 47,  42,  28, ..., 117, 146, 150],
#          [ 40,  39,  30, ..., 140, 159, 157]], dtype=uint8), 0],
#  [array([[ 77,  71,  35, ...,  76,  73,  73],
#          [ 77,  72,  43, ...,  75,  73,  73],
#          [ 78,  68,  39, ...,  75,  74,  74],
#          ...,
#          [168, 167, 167, ..., 234, 232, 232],
#          [165, 167, 164, ..., 234, 233, 233],
#          [165, 167, 164, ..., 234, 233, 233]], dtype=uint8), 0],
#  [array([[211, 211, 210, ..., 206, 206, 206],
#          [209, 209, 208, ..., 208, 212, 212],
#          [206, 205, 205, ..., 220, 216, 216],
#          ...,
#          [ 25,  21,  28, ...,  47,  50,  50],
#          [ 23,   1,  33, ...,  50,  48,  48],
#          [ 19,  19, 135, ...,  49,  50,  50]], dtype=uint8), 0],
#  [array([[120, 126, 111, ..., 204, 205, 205],
#          [121, 122, 107, ..., 208, 205, 205],
#          [126, 118, 107, ..., 207, 207, 207],
#          ...,
#          [169, 169, 170, ..., 221, 226, 226],
#          [167, 167, 167, ..., 227, 229, 229],
#          [167, 167, 167, ..., 231, 231, 232]], dtype=uint8), 0],
#  [array([[200, 198, 195, ..., 186, 196, 197],
#          [200, 198, 195, ..., 204, 205, 206],
#          [200, 199, 196, ..., 202, 200, 201],
#          ...,
#          [184, 156, 126, ..., 148, 165, 166],
#          [141, 106, 129, ..., 140, 150, 150],
#          [187, 103,  97, ..., 113, 111, 113]], dtype=uint8), 0],
#  [array([[ 26,  43,  23, ...,  86,   3,  10],
#          [ 46,  39,  25, ...,   7,  15,  21],
#          [ 34,  30,  31, ...,  13,  23,  28],
#          ...,
#          [176, 178, 180, ..., 234, 233, 233],
#          [179, 179, 180, ..., 233, 233, 233],
#          [179, 179, 180, ..., 233, 233, 233]], dtype=uint8), 0],
#  [array([[232, 232, 231, ..., 167, 168, 167],
#          [227, 227, 227, ..., 167, 167, 167],
#          [217, 218, 219, ..., 166, 169, 172],
#          ...,
#          [129, 144,  91, ..., 195, 202, 202],
#          [134, 112,  83, ..., 191, 197, 197],
#          [133, 106,  85, ..., 189, 192, 193]], dtype=uint8), 0],
#  [array([[  2, 168, 155, ...,  21,  36,  42],
#          [ 19,  88, 125, ...,  33,  46,  45],
#          [  5,  28, 132, ...,  33,  57,  54],
#          ...,
#          [200, 198, 196, ..., 165, 164, 164],
#          [204, 201, 197, ..., 160, 166, 165],
#          [204, 201, 197, ..., 172, 166, 165]], dtype=uint8), 0],
#  [array([[189, 189, 188, ..., 173, 172, 173],
#          [192, 192, 190, ..., 174, 174, 175],
#          [195, 194, 192, ..., 175, 176, 176],
#          ...,
#          [ 31,  20,  14, ..., 123, 121, 122],
#          [ 21,  17,  14, ..., 127, 126, 121],
#          [ 23,  21,  17, ..., 120, 126, 121]], dtype=uint8), 0],
#  [array([[226, 225, 223, ..., 188, 186, 188],
#          [226, 225, 224, ..., 183, 187, 189],
#          [226, 225, 224, ..., 186, 196, 198],
#          ...,
#          [217, 217, 218, ..., 157, 142, 142],
#          [223, 220, 220, ..., 135,  73, 119],
#          [221, 218, 217, ..., 141, 104, 139]], dtype=uint8), 0],
#  [array([[206, 152, 102, ..., 236, 240, 240],
#          [218, 155,  98, ..., 238, 241, 241],
#          [243, 204, 178, ..., 241, 243, 243],
#          ...,
#          [230, 230, 230, ..., 230, 231, 231],
#          [229, 230, 230, ..., 230, 231, 231],
#          [229, 230, 230, ..., 230, 231, 231]], dtype=uint8), 0],
#  [array([[188, 173, 187, ..., 180, 183, 184],
#          [190, 185, 192, ..., 189, 199, 201],
#          [172, 182, 185, ..., 197, 202, 202],
#          ...,
#          [ 65,  31,  21, ...,  75,   5,  10],
#          [ 77,  35,  25, ..., 122,  11,   2],
#          [ 74,  39,  30, ..., 128,  19,   6]], dtype=uint8), 0],
#  [array([[146, 168, 171, ..., 219, 215, 215],
#          [134, 157, 167, ..., 210, 204, 204],
#          [122, 149, 161, ..., 204, 204, 204],
#          ...,
#          [173, 173, 173, ..., 229, 231, 231],
#          [169, 169, 168, ..., 230, 232, 232],
#          [169, 169, 168, ..., 230, 232, 232]], dtype=uint8), 0],
#  [array([[ 28,  37,  33, ...,  69,  80,  80],
#          [ 41,  33,  19, ...,  75,  80,  80],
#          [ 45,  33,  11, ...,  82,  80,  80],
#          ...,
#          [198, 195, 190, ..., 173, 175, 175],
#          [207, 204, 200, ..., 168, 172, 172],
#          [210, 208, 205, ..., 168, 170, 170]], dtype=uint8), 0],
#  [array([[ 69,  69,  73, ..., 122, 116, 116],
#          [ 71,  69,  70, ..., 127, 134, 135],
#          [ 73,  72,  71, ..., 150, 152, 153],
#          ...,
#          [230, 230, 230, ..., 229, 230, 230],
#          [230, 229, 229, ..., 231, 230, 230],
#          [230, 229, 229, ..., 231, 230, 230]], dtype=uint8), 0],
#  [array([[ 88, 149, 149, ...,  31,   9,  15],
#          [ 77, 128, 154, ...,  24,  45,  50],
#          [ 72, 101, 153, ..., 127, 180, 184],
#          ...,
#          [183, 187, 193, ..., 181, 178, 176],
#          [194, 194, 194, ..., 182, 178, 176],
#          [198, 198, 199, ..., 182, 179, 177]], dtype=uint8), 0],
#  [array([[167, 177, 161, ...,  99, 112, 118],
#          [163, 174, 167, ..., 131, 139, 144],
#          [157, 171, 173, ..., 154, 199, 203],
#          ...,
#          [186, 186, 186, ..., 207, 211, 211],
#          [180, 180, 180, ..., 210, 215, 216],
#          [180, 180, 180, ..., 212, 215, 216]], dtype=uint8), 0],
#  [array([[228, 228, 227, ..., 167, 176, 178],
#          [228, 228, 227, ..., 169, 167, 168],
#          [228, 228, 227, ..., 173, 168, 169],
#          ...,
#          [229, 228, 227, ..., 132, 147, 171],
#          [226, 225, 225, ..., 106, 162, 163],
#          [226, 225, 225, ..., 148, 147, 148]], dtype=uint8), 0],
#  [array([[222, 222, 222, ..., 190, 191, 191],
#          [213, 213, 213, ..., 192, 191, 191],
#          [191, 191, 191, ..., 195, 193, 193],
#          ...,
#          [ 83,  83,  83, ..., 117, 139, 137],
#          [ 83,  83,  83, ..., 111, 140, 138],
#          [ 83,  83,  83, ..., 111, 140, 138]], dtype=uint8), 0],
#  [array([[ 48,  48,  48, ..., 194, 164, 181],
#          [ 20,  20,  20, ..., 168, 201, 191],
#          [ 27,  27,  27, ..., 187, 134,  80],
#          ...,
#          [185, 185, 185, ..., 210, 215, 215],
#          [178, 178, 178, ..., 205, 215, 216],
#          [168, 168, 168, ..., 215, 217, 218]], dtype=uint8), 0],
#  [array([[157, 181, 172, ...,  84,  81,  81],
#          [124, 151, 152, ...,  95,  77,  77],
#          [134, 173, 183, ...,  56,  73,  73],
#          ...,
#          [212, 210, 207, ..., 166, 166, 166],
#          [211, 209, 207, ..., 166, 166, 166],
#          [211, 209, 207, ..., 166, 166, 166]], dtype=uint8), 0],
#  [array([[153, 150, 113, ..., 121, 135,  79],
#          [205, 188, 173, ..., 117, 134,  49],
#          [230, 212, 219, ..., 119, 122,  21],
#          ...,
#          [188, 190, 185, ..., 156,  80,  89],
#          [192, 190, 187, ..., 209, 194, 169],
#          [192, 190, 187, ..., 203, 221, 207]], dtype=uint8), 0],
#  [array([[227, 227, 228, ...,  70,  77,  82],
#          [228, 228, 228, ...,  72,  79,  81],
#          [228, 228, 228, ...,  68,  86,  84],
#          ...,
#          [230, 230, 230, ..., 236, 236, 236],
#          [230, 230, 230, ..., 235, 235, 235],
#          [230, 230, 230, ..., 235, 235, 235]], dtype=uint8), 0],
#  [array([[156, 141, 166, ..., 203, 191, 200],
#          [168, 133, 153, ..., 187, 209, 214],
#          [132, 148, 154, ..., 232, 215, 212],
#          ...,
#          [187, 187, 193, ..., 172, 171, 168],
#          [198, 201, 204, ..., 174, 172, 172],
#          [203, 205, 208, ..., 174, 172, 172]], dtype=uint8), 0],
#  [array([[182, 209, 224, ..., 219, 222, 222],
#          [168, 175, 192, ..., 219, 222, 222],
#          [160, 158, 169, ..., 220, 223, 223],
#          ...,
#          [143, 159, 124, ..., 204, 192, 183],
#          [139,  90, 157, ..., 179, 196, 205],
#          [130,  78, 145, ..., 193, 189, 199]], dtype=uint8), 0],
#  [array([[ 75,  54,  39, ...,  89,  75, 179],
#          [ 74,  50,  41, ...,  88,  93, 178],
#          [ 72,  44,  44, ...,  86, 107, 158],
#          ...,
#          [170, 171, 172, ..., 169, 187, 187],
#          [167, 167, 169, ..., 156, 160, 160],
#          [167, 167, 169, ..., 166, 159, 159]], dtype=uint8), 0],
#  [array([[149, 151, 145, ..., 110, 111, 111],
#          [147, 151, 152, ..., 155, 130, 130],
#          [236, 235, 230, ..., 158, 147, 147],
#          ...,
#          [229, 229, 229, ..., 230, 229, 229],
#          [230, 230, 230, ..., 231, 230, 230],
#          [230, 230, 230, ..., 231, 230, 230]], dtype=uint8), 0],
#  [array([[219, 215, 211, ..., 150, 129,  93],
#          [203, 216, 209, ..., 165,  98,  86],
#          [202, 184, 210, ..., 126,  81,  90],
#          ...,
#          [168, 174, 175, ..., 157, 159, 163],
#          [171, 171, 172, ..., 163, 160, 154],
#          [171, 171, 172, ..., 175, 162, 157]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 232, 231, 231],
#          [230, 230, 230, ..., 232, 233, 233],
#          [230, 230, 230, ..., 233, 236, 236],
#          ...,
#          [229, 229, 229, ...,  58,  59,  62],
#          [229, 230, 229, ...,  64,  64,  59],
#          [229, 231, 231, ...,  64,  60,  55]], dtype=uint8), 0],
#  [array([[223, 193,  50, ...,  42,  51,  53],
#          [215, 195,  49, ...,  38,  41,  77],
#          [207, 200,  52, ...,  34,  54, 133],
#          ...,
#          [222, 223, 224, ..., 169, 184, 186],
#          [229, 230, 231, ..., 167, 181, 183],
#          [231, 232, 233, ..., 167, 181, 183]], dtype=uint8), 0],
#  [array([[125, 109, 125, ..., 225, 205, 205],
#          [164, 134,  97, ..., 189, 206, 195],
#          [140, 130, 139, ..., 188, 126, 119],
#          ...,
#          [223, 227, 231, ..., 178, 175, 175],
#          [232, 233, 233, ..., 181, 179, 178],
#          [232, 233, 233, ..., 181, 179, 178]], dtype=uint8), 0],
#  [array([[191, 188, 187, ..., 226, 233, 233],
#          [199, 195, 190, ..., 226, 233, 233],
#          [196, 199, 202, ..., 226, 233, 233],
#          ...,
#          [126,  45,  45, ..., 210, 215, 215],
#          [ 78,  41,  33, ..., 215, 215, 215],
#          [ 51,  43,  38, ..., 215, 215, 215]], dtype=uint8), 0],
#  [array([[193, 194, 195, ..., 220, 231, 231],
#          [195, 195, 197, ..., 227, 201, 201],
#          [197, 198, 199, ..., 203, 248, 248],
#          ...,
#          [ 37,  39,  13, ..., 162,  83,  21],
#          [ 44,  35,  20, ..., 120, 158,   0],
#          [ 44,  39,  26, ..., 109, 186,  13]], dtype=uint8), 0],
#  [array([[213, 136,  68, ..., 111, 132, 134],
#          [137, 107,  89, ..., 124, 110,  96],
#          [ 75, 113, 112, ..., 139,  45,  15],
#          ...,
#          [208, 206, 204, ..., 167, 166, 166],
#          [206, 204, 202, ..., 167, 167, 167],
#          [206, 204, 202, ..., 167, 167, 167]], dtype=uint8), 0],
#  [array([[217, 217, 217, ..., 142, 126, 123],
#          [217, 217, 217, ..., 155, 139,  92],
#          [217, 217, 217, ..., 164, 130, 122],
#          ...,
#          [234, 233, 232, ..., 198, 201, 202],
#          [233, 231, 228, ..., 198, 203, 203],
#          [233, 231, 228, ..., 191, 194, 195]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 230, 231, 231],
#          [230, 230, 230, ..., 230, 231, 231],
#          [230, 230, 230, ..., 230, 231, 231],
#          ...,
#          [241, 237, 245, ..., 177, 151, 144],
#          [240, 240, 240, ..., 108, 130, 121],
#          [239, 239, 239, ..., 146, 130, 120]], dtype=uint8), 0],
#  [array([[  2,   3,  87, ...,  10,  13,  16],
#          [  7,  10,  31, ...,  10,  16,  16],
#          [ 15,  16,   9, ...,   0,  14,  12],
#          ...,
#          [164, 164, 163, ..., 208, 207, 208],
#          [159, 162, 166, ..., 207, 206, 206],
#          [173, 178, 184, ..., 207, 206, 206]], dtype=uint8), 0],
#  [array([[114, 118, 119, ..., 114, 121, 121],
#          [124, 127, 125, ..., 120, 118, 118],
#          [145, 148, 148, ..., 116, 124, 124],
#          ...,
#          [231, 231, 231, ..., 230, 230, 230],
#          [231, 231, 231, ..., 230, 230, 230],
#          [231, 231, 231, ..., 230, 230, 230]], dtype=uint8), 0],
#  [array([[176, 156, 156, ..., 180, 166, 166],
#          [209, 182, 162, ..., 176, 166, 166],
#          [194, 189, 170, ..., 172, 166, 166],
#          ...,
#          [135,  79,  97, ..., 207, 193, 199],
#          [101,  87, 144, ..., 206, 205, 203],
#          [ 90,  89, 153, ..., 206, 210, 207]], dtype=uint8), 0],
#  [array([[107, 106, 108, ...,  86,  75,  72],
#          [107, 106, 107, ...,  79,  74,  72],
#          [105, 104, 105, ...,  77,  67,  67],
#          ...,
#          [232, 232, 232, ..., 232, 232, 232],
#          [232, 232, 232, ..., 232, 232, 232],
#          [232, 232, 232, ..., 232, 232, 232]], dtype=uint8), 0],
#  [array([[229, 228, 228, ..., 171, 179, 180],
#          [230, 229, 228, ..., 171, 171, 172],
#          [231, 230, 228, ..., 173, 171, 172],
#          ...,
#          [225, 231, 224, ..., 138, 157, 139],
#          [228, 224, 233, ..., 164, 162, 162],
#          [230, 225, 232, ..., 149, 164, 164]], dtype=uint8), 0],
#  [array([[221, 220, 218, ..., 166, 163, 163],
#          [216, 215, 213, ..., 165, 165, 165],
#          [213, 212, 209, ..., 165, 167, 167],
#          ...,
#          [206, 184,  63, ...,  54,  80,  80],
#          [211, 206,  80, ...,  48,  71,  78],
#          [212, 212,  90, ...,  47,  71,  78]], dtype=uint8), 0],
#  [array([[148, 191, 156, ...,  44,  60,  66],
#          [153, 160, 151, ...,  47,  52,  69],
#          [191, 181, 153, ...,  41,  38,  77],
#          ...,
#          [207, 204, 201, ..., 195, 187, 187],
#          [208, 207, 206, ..., 228, 211, 212],
#          [208, 207, 206, ..., 211, 213, 214]], dtype=uint8), 0],
#  [array([[172, 172, 173, ..., 229, 231, 231],
#          [174, 174, 175, ..., 230, 233, 233],
#          [176, 177, 177, ..., 231, 235, 235],
#          ...,
#          [156, 157, 155, ...,  73,  77,  77],
#          [156, 157, 162, ...,  75,  75,  75],
#          [159, 159, 162, ...,  75,  75,  75]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 230, 230, 230],
#          [232, 232, 232, ..., 230, 230, 230],
#          [232, 232, 232, ..., 230, 230, 230],
#          ...,
#          [121, 122, 122, ..., 236, 233, 235],
#          [101, 104, 108, ..., 215, 236, 238],
#          [ 88,  91,  95, ..., 187, 236, 238]], dtype=uint8), 0],
#  [array([[217, 218, 217, ..., 169, 168, 168],
#          [218, 218, 218, ..., 166, 166, 166],
#          [216, 216, 215, ..., 168, 169, 169],
#          ...,
#          [152, 176, 168, ..., 190, 188, 188],
#          [127, 177, 137, ..., 193, 193, 193],
#          [134, 179, 136, ..., 193, 193, 193]], dtype=uint8), 0],
#  [array([[ 62,  72,  76, ..., 112, 111, 111],
#          [ 72,  79,  81, ..., 192, 179, 179],
#          [ 92,  92,  89, ..., 216, 227, 227],
#          ...,
#          [230, 230, 230, ..., 231, 230, 230],
#          [230, 230, 230, ..., 230, 230, 230],
#          [230, 230, 230, ..., 230, 230, 230]], dtype=uint8), 0],
#  [array([[199, 194, 189, ..., 171, 168, 168],
#          [217, 211, 202, ..., 170, 169, 168],
#          [227, 225, 218, ..., 169, 167, 168],
#          ...,
#          [122, 142,  70, ..., 203, 191, 191],
#          [135, 100,  84, ..., 200, 199, 204],
#          [134,  93,  86, ..., 192, 194, 201]], dtype=uint8), 0],
#  [array([[129, 124, 120, ..., 221, 218, 218],
#          [ 79, 132, 114, ..., 213, 216, 216],
#          [ 26, 128, 113, ..., 211, 215, 215],
#          ...,
#          [ 74, 165, 212, ..., 217, 215, 215],
#          [194, 200, 207, ..., 212, 215, 215],
#          [205, 208, 209, ..., 213, 215, 215]], dtype=uint8), 0],
#  [array([[228, 226, 224, ..., 175, 172, 172],
#          [230, 227, 224, ..., 176, 177, 177],
#          [231, 228, 224, ..., 178, 179, 179],
#          ...,
#          [181, 168, 150, ..., 103, 146, 152],
#          [135, 122, 107, ...,  60, 130, 151],
#          [102,  92,  82, ...,  85, 117, 144]], dtype=uint8), 0],
#  [array([[149, 152, 122, ..., 195, 202, 202],
#          [155, 155, 136, ..., 189, 199, 199],
#          [154, 152, 152, ..., 198, 194, 194],
#          ...,
#          [194, 203, 205, ..., 181, 182, 182],
#          [197, 188, 174, ..., 183, 182, 182],
#          [180, 173, 167, ..., 183, 182, 182]], dtype=uint8), 0],
#  [array([[ 77,  81,  76, ..., 213, 207, 203],
#          [ 77,  81,  78, ..., 198, 208, 205],
#          [ 78,  81,  80, ..., 195, 207, 204],
#          ...,
#          [188, 126,  89, ..., 192, 196, 198],
#          [102, 100, 145, ..., 191, 195, 197],
#          [119, 159, 195, ..., 191, 195, 197]], dtype=uint8), 0],
#  [array([[215, 215, 213, ..., 168, 167, 167],
#          [215, 215, 213, ..., 168, 167, 167],
#          [215, 215, 213, ..., 168, 167, 167],
#          ...,
#          [174, 172, 158, ..., 113, 169, 185],
#          [165, 163, 135, ...,  85, 204, 200],
#          [173, 169, 137, ...,  83, 197, 193]], dtype=uint8), 0],
#  [array([[  0, 139, 130, ..., 215, 219, 219],
#          [ 17,  93, 107, ..., 212, 209, 209],
#          [  0,  57, 122, ..., 211, 203, 203],
#          ...,
#          [186, 182, 178, ..., 218, 219, 220],
#          [167, 167, 167, ..., 218, 219, 220],
#          [167, 167, 167, ..., 218, 219, 220]], dtype=uint8), 0],
#  [array([[127, 108,  97, ...,  74,  76,  74],
#          [126, 115,  98, ...,  75,  73,  74],
#          [123, 124, 100, ...,  90, 107, 111],
#          ...,
#          [185, 179, 175, ..., 202, 207, 207],
#          [177, 177, 176, ..., 212, 212, 214],
#          [177, 177, 176, ..., 212, 214, 216]], dtype=uint8), 0],
#  [array([[167, 167, 167, ..., 209, 213, 213],
#          [167, 167, 167, ..., 209, 213, 213],
#          [167, 167, 167, ..., 210, 213, 213],
#          ...,
#          [  5,  33,   4, ..., 166, 179, 178],
#          [ 56,  53,  53, ..., 134, 173, 173],
#          [ 51,  49,  49, ..., 137, 143, 143]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 230, 230, 230],
#          [231, 231, 231, ..., 230, 230, 230],
#          [231, 231, 231, ..., 230, 230, 230],
#          ...,
#          [ 67,  92,  86, ..., 229, 226, 226],
#          [ 72,  88,  70, ..., 227, 227, 227],
#          [ 73,  89,  69, ..., 227, 227, 227]], dtype=uint8), 0],
#  [array([[ 80,  77,  78, ...,  72, 173,  29],
#          [ 80,  77,  78, ...,  72, 173,  29],
#          [ 80,  77,  78, ...,  72, 173,  29],
#          ...,
#          [168, 168, 167, ..., 168, 166, 163],
#          [165, 165, 164, ..., 173, 167, 166],
#          [165, 165, 164, ..., 173, 171, 170]], dtype=uint8), 0],
#  [array([[225, 226, 228, ..., 181, 177, 177],
#          [220, 221, 223, ..., 180, 177, 177],
#          [212, 213, 215, ..., 180, 177, 177],
#          ...,
#          [136, 136, 164, ..., 156, 177, 188],
#          [145, 150, 148, ..., 165, 193, 193],
#          [145, 150, 148, ..., 199, 203, 202]], dtype=uint8), 0],
#  [array([[ 49,  25,  30, ...,  28,  65,  68],
#          [ 24,  37,  28, ...,  33,  67,  69],
#          [ 48,  41,  24, ...,  40,  71,  72],
#          ...,
#          [185, 186, 188, ..., 197, 198, 196],
#          [186, 187, 190, ..., 204, 205, 205],
#          [186, 187, 190, ..., 209, 209, 209]], dtype=uint8), 0],
#  [array([[168, 169, 171, ..., 177, 201, 201],
#          [167, 168, 170, ..., 208, 186, 186],
#          [166, 167, 168, ..., 186, 209, 209],
#          ...,
#          [125,  65,  17, ...,  76, 123, 130],
#          [ 17,  29,  34, ...,  93,  89, 132],
#          [ 33,  44,  46, ..., 117,  70, 107]], dtype=uint8), 0],
#  [array([[227, 227, 227, ...,  69,  63,  62],
#          [227, 228, 228, ...,  68,  62,  66],
#          [226, 227, 229, ...,  66,  61,  69],
#          ...,
#          [230, 230, 230, ..., 241, 240, 238],
#          [230, 231, 232, ..., 236, 236, 236],
#          [230, 231, 232, ..., 236, 236, 236]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 232, 233, 233],
#          [230, 230, 230, ..., 232, 233, 233],
#          [230, 230, 230, ..., 232, 233, 233],
#          ...,
#          [248, 235, 212, ...,  86,  75,  75],
#          [185, 170, 153, ...,  76,  85,  80],
#          [158, 150, 139, ...,  76,  85,  80]], dtype=uint8), 0],
#  [array([[ 67,  74,  67, ..., 143, 165, 191],
#          [ 74,  70,  65, ..., 135, 197, 220],
#          [ 90,  69,  61, ..., 193, 236, 255],
#          ...,
#          [231, 231, 231, ..., 230, 230, 230],
#          [230, 230, 230, ..., 230, 230, 230],
#          [230, 230, 230, ..., 230, 230, 230]], dtype=uint8), 0],
#  [array([[153, 167, 177, ..., 220, 220, 220],
#          [155, 160, 155, ..., 202, 206, 206],
#          [156, 166, 157, ..., 181, 181, 181],
#          ...,
#          [ 74,  48,  13, ...,  50,  52,  52],
#          [ 74,  34,  11, ...,  71,  68,  68],
#          [ 74,  34,  11, ...,  76,  78,  78]], dtype=uint8), 0],
#  [array([[226, 227, 227, ...,  62,  65,  64],
#          [230, 230, 229, ...,  62,  62,  60],
#          [229, 229, 229, ...,  62,  62,  60],
#          ...,
#          [229, 229, 229, ..., 233, 235, 235],
#          [230, 230, 230, ..., 233, 234, 234],
#          [230, 230, 230, ..., 233, 234, 234]], dtype=uint8), 0],
#  [array([[176, 166, 160, ..., 220, 223, 223],
#          [177, 172, 169, ..., 220, 224, 224],
#          [184, 183, 182, ..., 221, 226, 226],
#          ...,
#          [171, 159, 116, ..., 216, 217, 217],
#          [175, 141, 118, ..., 214, 213, 213],
#          [161, 130, 138, ..., 214, 213, 213]], dtype=uint8), 0],
#  [array([[ 33,  48,  55, ..., 154, 145,  90],
#          [ 13,  14,  21, ..., 160, 121,  78],
#          [105,  64,  24, ..., 155,  96,  72],
#          ...,
#          [178, 164, 158, ..., 186, 184, 184],
#          [183, 173, 166, ..., 171, 166, 151],
#          [183, 174, 166, ..., 170, 184, 175]], dtype=uint8), 0],
#  [array([[204, 197, 197, ...,  62,   8,  21],
#          [215, 207, 200, ...,  17,  16,  30],
#          [203, 206, 208, ...,  18,  23,  36],
#          ...,
#          [181, 168, 164, ..., 207, 207, 207],
#          [168, 168, 168, ..., 212, 211, 211],
#          [168, 168, 168, ..., 217, 213, 213]], dtype=uint8), 0],
#  [array([[ 97,  96, 102, ..., 110, 109, 109],
#          [ 98,  96, 100, ..., 106, 107, 107],
#          [ 98,  96,  97, ..., 108, 109, 109],
#          ...,
#          [233, 233, 233, ..., 231, 230, 230],
#          [233, 233, 233, ..., 229, 231, 231],
#          [233, 233, 233, ..., 229, 231, 231]], dtype=uint8), 0],
#  [array([[168, 166, 166, ..., 218, 218, 218],
#          [168, 166, 166, ..., 214, 212, 211],
#          [168, 166, 166, ..., 208, 210, 210],
#          ...,
#          [207, 213, 215, ..., 171, 164, 170],
#          [218, 215, 210, ..., 178, 165, 189],
#          [207, 204, 200, ..., 146, 144, 173]], dtype=uint8), 0],
#  [array([[181, 187, 164, ...,  29,  79, 140],
#          [207, 202, 193, ...,  39, 137, 197],
#          [197, 190, 199, ...,  49, 156, 212],
#          ...,
#          [165, 173, 183, ..., 234, 233, 233],
#          [168, 177, 180, ..., 234, 233, 233],
#          [168, 177, 180, ..., 234, 233, 233]], dtype=uint8), 0],
#  [array([[136, 136, 136, ..., 154, 162, 144],
#          [154, 154, 154, ..., 147, 103,  87],
#          [233, 233, 233, ...,  65,  75,  66],
#          ...,
#          [231, 231, 231, ..., 229, 230, 229],
#          [231, 231, 231, ..., 229, 230, 229],
#          [231, 231, 231, ..., 229, 230, 229]], dtype=uint8), 0],
#  [array([[146, 164, 176, ..., 187, 183, 183],
#          [160, 158, 163, ..., 192, 187, 187],
#          [178, 162, 156, ..., 194, 194, 194],
#          ...,
#          [ 93,  93,  71, ...,  69,  60,  59],
#          [ 92,  80, 102, ...,  79,  79,  79],
#          [ 92,  80, 102, ...,  79,  79,  79]], dtype=uint8), 0],
#  [array([[127,  94,  71, ...,  93,  96,  96],
#          [116,  88,  68, ..., 115, 118, 119],
#          [120,  99,  80, ..., 116, 114, 115],
#          ...,
#          [234, 234, 234, ..., 233, 232, 232],
#          [233, 233, 233, ..., 233, 232, 232],
#          [233, 233, 233, ..., 233, 232, 232]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 233, 232, 232],
#          [232, 232, 232, ..., 233, 232, 232],
#          [233, 233, 233, ..., 233, 232, 232],
#          ...,
#          [ 84,  71,  78, ...,  98,  97,  97],
#          [ 83,  81,  73, ...,  97,  97,  97],
#          [ 83,  81,  73, ...,  97,  97,  97]], dtype=uint8), 0],
#  [array([[204, 203, 203, ..., 219, 217, 217],
#          [215, 214, 214, ..., 216, 217, 217],
#          [213, 215, 217, ..., 216, 217, 218],
#          ...,
#          [ 15,  28,  49, ..., 107,  86, 143],
#          [ 20,  19,  19, ...,  56,  74, 205],
#          [ 45,  40,  35, ...,  34,  65, 196]], dtype=uint8), 0],
#  [array([[166, 168, 173, ..., 221, 224, 224],
#          [165, 167, 172, ..., 222, 224, 224],
#          [164, 166, 170, ..., 222, 224, 224],
#          ...,
#          [205, 203, 200, ..., 145, 111, 118],
#          [181, 182, 184, ..., 142, 127, 114],
#          [125, 101,  68, ..., 140, 124, 111]], dtype=uint8), 0],
#  [array([[230, 230, 230, ..., 235, 232, 232],
#          [230, 230, 230, ..., 232, 230, 230],
#          [230, 230, 230, ..., 230, 231, 231],
#          ...,
#          [224, 224, 225, ...,  65,  93,  77],
#          [228, 228, 228, ...,  73,  71,  88],
#          [228, 228, 228, ...,  73,  75,  93]], dtype=uint8), 0],
#  [array([[ 62,  73,  65, ..., 231, 228, 228],
#          [ 69,  62,  68, ..., 228, 228, 228],
#          [ 75,  54,  71, ..., 234, 228, 228],
#          ...,
#          [239, 239, 238, ..., 228, 230, 230],
#          [239, 238, 237, ..., 231, 230, 230],
#          [239, 238, 237, ..., 231, 230, 230]], dtype=uint8), 0],
#  [array([[218, 217, 216, ..., 166, 164, 164],
#          [211, 210, 208, ..., 165, 165, 165],
#          [205, 204, 201, ..., 165, 166, 166],
#          ...,
#          [ 36,  42,  28, ...,  86,  81,  81],
#          [ 51,  34,  23, ...,  83,  80,  80],
#          [ 46,  27,  11, ...,  79,  80,  80]], dtype=uint8), 0],
#  [array([[109, 108, 111, ...,  80,  65,  66],
#          [109, 108, 110, ...,  85,  67,  68],
#          [109, 107, 110, ...,  86,  67,  68],
#          ...,
#          [232, 232, 232, ..., 231, 230, 230],
#          [231, 231, 231, ..., 230, 228, 228],
#          [231, 231, 231, ..., 230, 228, 228]], dtype=uint8), 0],
#  [array([[ 29,  12,  37, ..., 156, 152, 147],
#          [148,  66,  21, ..., 156, 154, 156],
#          [188, 180, 140, ..., 150, 146, 148],
#          ...,
#          [185, 188, 192, ..., 229, 224, 224],
#          [191, 191, 195, ..., 215, 213, 230],
#          [191, 191, 195, ..., 190, 201, 219]], dtype=uint8), 0],
#  [array([[238, 238, 237, ..., 229, 230, 230],
#          [238, 238, 238, ..., 229, 230, 230],
#          [239, 239, 238, ..., 229, 230, 230],
#          ...,
#          [ 75,  74,  84, ..., 226, 229, 229],
#          [ 74,  83,  79, ..., 229, 229, 229],
#          [ 74,  83,  79, ..., 233, 229, 229]], dtype=uint8), 0],
#  [array([[187, 171, 163, ..., 172, 204, 204],
#          [186, 175, 166, ..., 164, 182, 180],
#          [185, 180, 172, ..., 179, 163, 161],
#          ...,
#          [205, 202, 206, ..., 162, 159, 149],
#          [211, 206, 202, ..., 151, 151, 151],
#          [212, 206, 202, ..., 156, 155, 156]], dtype=uint8), 0],
#  [array([[207, 206, 205, ..., 168, 170, 170],
#          [209, 208, 206, ..., 169, 169, 169],
#          [211, 210, 208, ..., 169, 170, 170],
#          ...,
#          [209, 202, 209, ..., 155, 121, 126],
#          [208, 205, 202, ..., 148, 147, 130],
#          [206, 204, 202, ..., 143, 160, 153]], dtype=uint8), 0],
#  [array([[164, 166, 167, ..., 227, 231, 231],
#          [164, 166, 167, ..., 226, 232, 232],
#          [164, 166, 167, ..., 226, 231, 231],
#          ...,
#          [193, 194, 196, ..., 146, 142, 153],
#          [202, 202, 205, ..., 154, 151, 151],
#          [188, 184, 186, ..., 153, 151, 151]], dtype=uint8), 0],
#  [array([[185, 184, 185, ..., 232, 233, 233],
#          [194, 192, 188, ..., 233, 233, 233],
#          [203, 202, 195, ..., 233, 233, 233],
#          ...,
#          [ 46,  34,  28, ..., 222, 216, 216],
#          [ 49,  42,  10, ..., 184, 202, 200],
#          [ 31,  23,  33, ..., 197, 193, 191]], dtype=uint8), 0],
#  [array([[213, 212, 212, ..., 168, 167, 167],
#          [206, 206, 206, ..., 168, 166, 166],
#          [199, 199, 199, ..., 176, 180, 180],
#          ...,
#          [ 84, 140, 150, ...,  79,  79,  79],
#          [ 89, 146, 149, ...,  80,  80,  80],
#          [ 89, 146, 149, ...,  80,  80,  80]], dtype=uint8), 0],
#  [array([[ 19,  40,  55, ..., 125, 147, 110],
#          [ 26,  18,  16, ..., 143, 131, 113],
#          [180, 119,  53, ..., 148, 112, 121],
#          ...,
#          [170, 171, 173, ..., 169, 140, 140],
#          [171, 173, 175, ..., 205, 180, 178],
#          [171, 173, 175, ..., 203, 212, 211]], dtype=uint8), 0],
#  [array([[193, 193, 193, ...,  14,  30,  31],
#          [188, 188, 188, ...,  27,  33,  39],
#          [192, 192, 192, ...,  20,  21,  30],
#          ...,
#          [170, 170, 170, ..., 225, 228, 228],
#          [166, 166, 166, ..., 225, 227, 227],
#          [166, 166, 166, ..., 225, 227, 227]], dtype=uint8), 0],
#  [array([[191, 193, 191, ..., 193, 200, 200],
#          [201, 203, 203, ..., 192, 195, 195],
#          [205, 206, 210, ..., 190, 190, 190],
#          ...,
#          [ 51,  48,  50, ..., 125,  94, 109],
#          [ 54,  51,  50, ..., 143, 140, 138],
#          [ 70,  67,  65, ..., 142, 153, 151]], dtype=uint8), 0],
#  [array([[193, 191, 192, ..., 145,  66,  13],
#          [194, 185, 193, ..., 154,  37,   2],
#          [202, 200, 205, ..., 173,  10,   0],
#          ...,
#          [168, 169, 171, ..., 155, 157, 161],
#          [170, 171, 173, ..., 151, 157, 155],
#          [170, 171, 173, ..., 165, 159, 157]], dtype=uint8), 0],
#  [array([[229, 240, 233, ...,  65,  72,  72],
#          [235, 244, 236, ...,  58,  67,  68],
#          [239, 246, 242, ...,  49,  75,  81],
#          ...,
#          [230, 230, 230, ..., 231, 233, 233],
#          [230, 230, 230, ..., 231, 231, 231],
#          [230, 230, 230, ..., 231, 231, 231]], dtype=uint8), 0],
#  [array([[ 41,  48,  53, ..., 143,   1,   6],
#          [ 60,  61,  52, ..., 119,   3,   8],
#          [ 11,  29,  38, ...,  95,   5,  10],
#          ...,
#          [203, 178, 158, ..., 209, 205, 204],
#          [197, 198, 168, ..., 207, 202, 208],
#          [197, 198, 168, ..., 175, 174, 180]], dtype=uint8), 0],
#  [array([[223, 218, 212, ..., 167, 168, 167],
#          [209, 217, 214, ..., 167, 166, 166],
#          [213, 225, 217, ..., 168, 165, 164],
#          ...,
#          [128, 130, 112, ..., 191, 190, 190],
#          [136, 124,  84, ..., 186, 199, 193],
#          [133, 119,  82, ..., 208, 201, 196]], dtype=uint8), 0],
#  [array([[ 70,  53,  31, ..., 183, 183, 183],
#          [124,  41,  21, ..., 198, 189, 189],
#          [154,  64,  15, ..., 200, 203, 203],
#          ...,
#          [225, 223, 220, ..., 165, 165, 165],
#          [224, 223, 221, ..., 166, 166, 166],
#          [224, 223, 221, ..., 166, 166, 166]], dtype=uint8), 0],
#  [array([[176, 178, 179, ..., 185, 181, 181],
#          [186, 184, 181, ..., 176, 182, 182],
#          [208, 198, 187, ..., 187, 184, 184],
#          ...,
#          [118, 127, 114, ...,  28,  13,  19],
#          [126, 118, 101, ...,   1,  11,  17],
#          [127, 118, 101, ...,   2,  11,  17]], dtype=uint8), 0],
#  [array([[168, 164, 163, ..., 216, 218, 218],
#          [163, 163, 163, ..., 216, 218, 218],
#          [161, 163, 164, ..., 217, 218, 218],
#          ...,
#          [  9,  39, 141, ..., 213, 223, 221],
#          [  5,  20, 186, ..., 212, 216, 216],
#          [ 14,   8, 122, ..., 214, 216, 216]], dtype=uint8), 0],
#  [array([[ 75,  72,  70, ..., 102, 108, 108],
#          [ 74,  73,  72, ..., 109, 108, 108],
#          [ 73,  74,  75, ..., 110, 108, 108],
#          ...,
#          [233, 233, 233, ..., 231, 231, 231],
#          [233, 233, 233, ..., 230, 231, 231],
#          [233, 233, 233, ..., 230, 231, 231]], dtype=uint8), 0],
#  [array([[234, 233, 232, ..., 170, 171, 169],
#          [234, 233, 232, ..., 170, 171, 168],
#          [234, 233, 232, ..., 170, 170, 167],
#          ...,
#          [205, 204, 205, ..., 136, 143, 148],
#          [201, 205, 201, ..., 155, 164, 151],
#          [199, 203, 199, ..., 159, 165, 151]], dtype=uint8), 0],
#  [array([[ 28,  19,   5, ...,  48,  76,  75],
#          [ 13,  32,   2, ...,  67,  73,  71],
#          [ 15,  19,  19, ...,  79,  78,  75],
#          ...,
#          [194, 196, 199, ..., 231, 229, 229],
#          [199, 198, 198, ..., 233, 233, 233],
#          [199, 198, 198, ..., 233, 233, 233]], dtype=uint8), 0],
#  [array([[ 17,  19,  22, ..., 123, 142, 106],
#          [194, 133,  57, ..., 138, 129, 113],
#          [164, 185, 198, ..., 148, 114, 123],
#          ...,
#          [179, 165, 160, ..., 195, 206, 206],
#          [166, 167, 168, ..., 165, 188, 190],
#          [166, 167, 168, ..., 156, 155, 157]], dtype=uint8), 0],
#  [array([[229, 229, 229, ..., 231, 231, 231],
#          [229, 229, 229, ..., 231, 231, 231],
#          [229, 229, 229, ..., 230, 230, 230],
#          ...,
#          [ 53,  66,  58, ..., 119, 119, 119],
#          [ 67,  59,  65, ...,  93,  93,  93],
#          [ 64,  57,  65, ...,  91,  91,  91]], dtype=uint8), 0],
#  [array([[165, 168, 163, ...,  49,  30,  18],
#          [160, 168, 165, ...,  64,  25,  61],
#          [149, 167, 167, ...,  89, 189, 199],
#          ...,
#          [161, 161, 167, ..., 218, 219, 219],
#          [179, 195, 217, ..., 223, 219, 219],
#          [219, 224, 227, ..., 223, 219, 219]], dtype=uint8), 0],
#  [array([[ 71,  75,  78, ..., 241, 243, 243],
#          [ 51,  57,  63, ..., 248, 249, 249],
#          [ 61,  59,  54, ..., 251, 247, 247],
#          ...,
#          [229, 229, 229, ..., 230, 231, 231],
#          [230, 229, 229, ..., 230, 231, 231],
#          [230, 229, 229, ..., 230, 231, 231]], dtype=uint8), 0],
#  [array([[ 42,  20,  14, ...,  82,  78,  78],
#          [ 23,  23,  16, ...,  79,  80,  80],
#          [ 28,  36,  27, ...,  81,  78,  78],
#          ...,
#          [208, 207, 207, ..., 188, 171, 171],
#          [207, 207, 207, ..., 225, 206, 206],
#          [207, 207, 207, ..., 211, 217, 218]], dtype=uint8), 0],
#  [array([[138, 131, 174, ...,  79,  78,  78],
#          [ 58,  45, 143, ...,  77,  81,  81],
#          [163, 163, 203, ...,  71,  66,  66],
#          ...,
#          [197, 190, 184, ..., 163, 163, 163],
#          [196, 197, 197, ..., 184, 181, 181],
#          [198, 199, 199, ..., 215, 211, 211]], dtype=uint8), 0],
#  [array([[213, 209, 204, ..., 170, 171, 177],
#          [204, 200, 195, ..., 175, 175, 177],
#          [195, 192, 189, ..., 177, 175, 175],
#          ...,
#          [ 93,  79,  73, ..., 109, 125, 121],
#          [ 73,  75,  73, ..., 102, 114, 127],
#          [ 72,  74,  73, ..., 100, 114, 126]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 232, 231, 231],
#          [232, 232, 232, ..., 232, 233, 233],
#          [232, 232, 232, ..., 232, 234, 234],
#          ...,
#          [112, 110, 113, ...,  66,  66,  64],
#          [109, 107, 110, ...,  73,  68,  68],
#          [109, 107, 110, ...,  73,  68,  68]], dtype=uint8), 0],
#  [array([[218, 215, 211, ..., 206, 208, 167],
#          [217, 215, 212, ..., 182,  98,  88],
#          [216, 214, 212, ..., 127, 143, 163],
#          ...,
#          [205, 211, 216, ..., 128, 144, 146],
#          [209, 209, 210, ...,  75, 140, 150],
#          [209, 209, 210, ...,  74, 135, 147]], dtype=uint8), 0],
#  [array([[154, 150, 152, ...,  80,  80,  80],
#          [153, 150, 152, ...,  80,  80,  80],
#          [153, 149, 152, ...,  80,  80,  80],
#          ...,
#          [194, 168, 185, ..., 165, 163, 163],
#          [184, 185, 185, ..., 182, 182, 182],
#          [184, 185, 185, ..., 184, 217, 217]], dtype=uint8), 0],
#  [array([[170, 169, 165, ..., 231, 233, 233],
#          [166, 166, 165, ..., 230, 233, 233],
#          [164, 166, 165, ..., 230, 232, 232],
#          ...,
#          [ 15,  16,  25, ...,  39, 112, 221],
#          [ 51,  51,  48, ...,  31, 103, 152],
#          [ 46,  46,  44, ...,  36,  70, 119]], dtype=uint8), 0],
#  [array([[ 81,  83,  78, ...,  67,  74,  74],
#          [ 81,  83,  78, ...,  64,  74,  74],
#          [ 81,  83,  79, ...,  56,  72,  72],
#          ...,
#          [218, 217, 215, ..., 211, 214, 214],
#          [205, 205, 205, ..., 224, 223, 223],
#          [197, 197, 197, ..., 224, 227, 228]], dtype=uint8), 0],
#  [array([[ 29,  20,   8, ...,  76,  76,  76],
#          [ 40,  19,  35, ...,  82,  79,  79],
#          [ 36,  38,  40, ..., 109,  98,  98],
#          ...,
#          [172, 172, 174, ..., 169, 170, 170],
#          [169, 170, 172, ..., 158, 159, 159],
#          [169, 170, 172, ..., 158, 159, 159]], dtype=uint8), 0],
#  [array([[185, 185, 179, ..., 227, 230, 230],
#          [183, 185, 181, ..., 227, 231, 231],
#          [181, 185, 183, ..., 225, 229, 229],
#          ...,
#          [198, 200, 202, ...,  69, 141, 149],
#          [200, 199, 198, ..., 100, 126, 123],
#          [196, 195, 193, ..., 118, 131, 127]], dtype=uint8), 0],
#  [array([[222, 223, 225, ..., 190, 196, 196],
#          [215, 213, 211, ..., 201, 198, 198],
#          [251, 244, 233, ..., 200, 199, 199],
#          ...,
#          [ 85, 102, 105, ...,  15,  29,  37],
#          [ 95, 106,  93, ...,  22,  37,  38],
#          [ 96, 109,  98, ...,  27,  38,  38]], dtype=uint8), 0],
#  [array([[162, 162, 164, ..., 198, 198, 198],
#          [162, 162, 161, ..., 200, 199, 199],
#          [167, 166, 164, ..., 201, 199, 200],
#          ...,
#          [ 40,  31,  24, ..., 166, 114,  20],
#          [ 33,  25,  21, ..., 147, 102,   2],
#          [ 36,  22,  16, ..., 127, 166,  66]], dtype=uint8), 0],
#  [array([[133, 101, 138, ..., 197, 192, 192],
#          [137, 132, 111, ..., 194, 197, 197],
#          [151, 149, 106, ..., 198, 202, 202],
#          ...,
#          [170, 189, 208, ..., 199, 194, 194],
#          [213, 212, 208, ..., 203, 199, 198],
#          [207, 200, 187, ..., 203, 199, 198]], dtype=uint8), 0],
#  [array([[233, 233, 232, ..., 167, 174, 180],
#          [233, 232, 232, ..., 167, 175, 180],
#          [233, 232, 232, ..., 167, 175, 179],
#          ...,
#          [ 79,  73,  71, ..., 125,   3,   4],
#          [ 73,  75,  72, ..., 122,   2,   7],
#          [ 73,  75,  72, ..., 122,   2,   7]], dtype=uint8), 0],
#  [array([[146, 160, 133, ..., 179, 194, 194],
#          [146, 157, 137, ..., 199, 200, 200],
#          [147, 154, 142, ..., 210, 197, 197],
#          ...,
#          [217, 202, 221, ..., 165, 193, 190],
#          [220, 219, 221, ..., 165, 183, 183],
#          [220, 219, 221, ..., 168, 183, 183]], dtype=uint8), 0],
#  [array([[232, 232, 232, ..., 232, 232, 232],
#          [232, 232, 232, ..., 232, 233, 233],
#          [232, 232, 232, ..., 232, 233, 233],
#          ...,
#          [ 65,  91,  84, ..., 106, 102, 102],
#          [ 66,  93,  76, ..., 108, 108, 108],
#          [ 66,  93,  76, ..., 108, 108, 108]], dtype=uint8), 0],
#  [array([[116, 107, 116, ..., 203, 210, 210],
#          [139, 109,  90, ..., 210, 213, 213],
# ...
#          [219, 210, 204, ..., 181, 179, 179],
#          ...,
#          [ 33,  29,  39, ..., 176, 177, 177],
#          [ 27,  30,  47, ..., 177, 176, 176],
#          [ 28,  35,  56, ..., 172, 176, 176]], dtype=uint8), 2],
#  [array([[162, 163, 192, ..., 169, 173, 173],
#          [141, 185, 179, ..., 166, 168, 168],
#          [150, 146, 161, ..., 181, 183, 183],
#          ...,
#          [ 89,  92,  92, ...,  92,  85,  85],
#          [ 95,  88,  89, ...,  85,  84,  84],
#          [ 95,  88,  89, ...,  85,  84,  84]], dtype=uint8), 2],
#  [array([[192, 191, 185, ..., 188, 187, 187],
#          [197, 198, 190, ..., 186, 193, 193],
#          [203, 209, 198, ..., 195, 197, 197],
#          ...,
#          [202, 204, 206, ..., 185, 183, 183],
#          [203, 203, 203, ..., 185, 182, 182],
#          [203, 203, 203, ..., 185, 182, 182]], dtype=uint8), 2],
#  [array([[232, 229, 227, ..., 224, 106,  47],
#          [232, 220, 222, ..., 201,  67,  37],
#          [239, 232, 210, ..., 156,  34,  42],
#          ...,
#          [100,  76,  94, ...,  90,  79,  79],
#          [ 90,  79,  83, ...,  65,  92,  89],
#          [ 88,  78,  79, ...,  50,  31,  27]], dtype=uint8), 2],
#  [array([[199, 200, 201, ..., 158, 163, 165],
#          [198, 199, 200, ..., 169, 163, 164],
#          [197, 198, 199, ..., 168, 193, 194],
#          ...,
#          [197, 197, 197, ..., 181, 182, 182],
#          [194, 198, 185, ..., 171, 181, 186],
#          [182, 163, 151, ..., 171, 181, 186]], dtype=uint8), 2],
#  [array([[200, 200, 200, ..., 168, 173, 167],
#          [246, 236, 221, ..., 168, 175, 172],
#          [203, 219, 241, ..., 188, 177, 177],
#          ...,
#          [175, 176, 177, ..., 184, 191, 191],
#          [176, 176, 175, ..., 197, 191, 191],
#          [176, 176, 175, ..., 197, 199, 199]], dtype=uint8), 2],
#  [array([[176, 176, 176, ...,  70,  78,  67],
#          [179, 181, 183, ...,  78,  71,  61],
#          [173, 174, 174, ...,  69,  65,  54],
#          ...,
#          [177, 179, 181, ..., 176, 173, 173],
#          [180, 179, 179, ..., 171, 172, 172],
#          [180, 179, 179, ..., 171, 172, 172]], dtype=uint8), 2],
#  [array([[ 64,  23,  12, ..., 179, 179, 179],
#          [ 65,  35,  24, ..., 174, 174, 174],
#          [ 59,  25,  21, ..., 181, 181, 181],
#          ...,
#          [193, 180, 200, ..., 179, 179, 179],
#          [184, 186, 189, ..., 179, 179, 179],
#          [184, 186, 189, ..., 179, 179, 179]], dtype=uint8), 2],
#  [array([[ 91, 108, 108, ...,  55,  84,  84],
#          [110, 117, 114, ...,  98,  93,  93],
#          [172, 164, 156, ...,  98,  95,  95],
#          ...,
#          [228, 231, 233, ..., 147, 155, 147],
#          [228, 230, 229, ..., 139, 154, 156],
#          [228, 230, 229, ..., 131, 154, 156]], dtype=uint8), 2],
#  [array([[203, 161,  44, ..., 180, 179, 179],
#          [204, 175,  61, ..., 171, 170, 170],
#          [205, 193,  84, ..., 175, 177, 177],
#          ...,
#          [187, 201, 206, ..., 179, 179, 179],
#          [203, 189, 198, ..., 179, 179, 179],
#          [179, 169, 183, ..., 179, 179, 179]], dtype=uint8), 2],
#  [array([[248, 239, 226, ..., 190, 182, 182],
#          [194, 208, 229, ..., 186, 180, 180],
#          [226, 215, 201, ..., 176, 180, 180],
#          ...,
#          [189, 189, 193, ..., 172, 169, 169],
#          [189, 191, 196, ..., 179, 177, 177],
#          [188, 188, 190, ..., 183, 181, 181]], dtype=uint8), 2],
#  [array([[ 46,  48,  54, ..., 165, 176, 176],
#          [ 43,  45,  49, ..., 179, 172, 172],
#          [ 44,  44,  47, ..., 155, 152, 154],
#          ...,
#          [149, 114,  86, ...,   8,  32,  26],
#          [ 82,  62,  45, ...,   3,  22,  27],
#          [ 51, 115, 187, ...,   7,  22,  27]], dtype=uint8), 2],
#  [array([[165, 176, 183, ..., 179, 185, 185],
#          [163, 174, 181, ..., 185, 185, 185],
#          [162, 171, 179, ..., 183, 189, 189],
#          ...,
#          [178, 180, 175, ..., 184, 175, 175],
#          [179, 178, 178, ..., 181, 172, 172],
#          [179, 178, 178, ..., 181, 182, 181]], dtype=uint8), 2],
#  [array([[201, 201, 201, ..., 191, 192, 192],
#          [201, 201, 201, ..., 192, 192, 192],
#          [201, 201, 201, ..., 192, 192, 192],
#          ...,
#          [143, 144, 147, ..., 186, 186, 184],
#          [185, 184, 184, ..., 183, 180, 180],
#          [177, 177, 176, ..., 183, 180, 180]], dtype=uint8), 2],
#  [array([[212, 215, 219, ...,  62, 108,  77],
#          [221, 197, 203, ...,  81,  89,  82],
#          [189, 188, 213, ...,  77,  64,  85],
#          ...,
#          [136, 143, 154, ..., 226, 231, 230],
#          [194, 202, 212, ..., 231, 230, 230],
#          [214, 218, 223, ..., 231, 230, 230]], dtype=uint8), 2],
#  [array([[145, 153, 162, ...,  59,  76, 154],
#          [171, 160, 149, ...,  65,  94, 175],
#          [179, 174, 166, ...,  72, 116, 186],
#          ...,
#          [181, 164, 184, ..., 224, 235, 235],
#          [179, 181, 183, ..., 165, 207, 216],
#          [179, 181, 183, ..., 194, 173, 176]], dtype=uint8), 2],
#  [array([[184, 197, 185, ..., 201, 201, 201],
#          [184, 193, 184, ..., 200, 201, 201],
#          [188, 191, 191, ..., 201, 201, 201],
#          ...,
#          [182, 178, 178, ..., 175, 173, 173],
#          [181, 178, 178, ..., 173, 173, 173],
#          [181, 178, 178, ..., 173, 173, 173]], dtype=uint8), 2],
#  [array([[178, 179, 182, ..., 199, 202, 202],
#          [178, 179, 182, ..., 202, 202, 202],
#          [178, 179, 181, ..., 206, 202, 202],
#          ...,
#          [200, 199, 197, ...,  28,  29,  53],
#          [251, 249, 247, ...,  29,  19,  48],
#          [209, 208, 206, ...,  39,  55,  95]], dtype=uint8), 2],
#  [array([[182, 201, 189, ..., 205, 202, 201],
#          [185, 198, 188, ..., 204, 201, 201],
#          [189, 195, 187, ..., 203, 201, 200],
#          ...,
#          [191, 189, 180, ..., 205, 210, 200],
#          [190, 186, 180, ..., 201, 208, 200],
#          [191, 189, 186, ..., 196, 193, 186]], dtype=uint8), 2],
#  [array([[228, 230, 228, ...,  94,  93,  93],
#          [235, 223, 234, ...,  91,  89,  89],
#          [244, 220, 238, ...,  88,  95,  95],
#          ...,
#          [134, 129, 113, ...,  49,  57,  57],
#          [ 84,  63,  75, ...,  59,  50,  50],
#          [ 38,  47,  94, ...,  78,  84,  84]], dtype=uint8), 2],
#  [array([[170, 178, 174, ..., 194, 216, 219],
#          [171, 176, 174, ..., 228, 226, 229],
#          [175, 177, 180, ..., 236, 236, 237],
#          ...,
#          [178, 180, 182, ...,  12,  16,  23],
#          [186, 187, 187, ...,   0,  14,  20],
#          [189, 189, 189, ...,  18,  10,  15]], dtype=uint8), 2],
#  [array([[179, 179, 179, ..., 211, 213, 214],
#          [178, 177, 177, ..., 214, 220, 219],
#          [180, 178, 177, ..., 216, 220, 219],
#          ...,
#          [158, 158, 165, ..., 200, 203, 203],
#          [180, 179, 179, ..., 201, 202, 202],
#          [180, 179, 179, ..., 200, 202, 202]], dtype=uint8), 2],
#  [array([[ 90,  84,  39, ..., 180, 180, 180],
#          [ 81,  92,  91, ..., 177, 182, 182],
#          [ 48,  67, 117, ..., 181, 175, 175],
#          ...,
#          [169, 170, 173, ..., 178, 180, 180],
#          [160, 166, 173, ..., 180, 179, 179],
#          [160, 166, 173, ..., 180, 179, 179]], dtype=uint8), 2],
#  [array([[ 45,  52,  43, ..., 101,  88,  77],
#          [ 38,  49,  41, ...,  68,  56,  65],
#          [ 40,  51,  47, ...,  67,  84, 110],
#          ...,
#          [ 22,  32,  37, ...,  54,  72,  79],
#          [ 37,  42,  46, ...,  74,  83,  83],
#          [ 42,  48,  53, ...,  79,  79,  79]], dtype=uint8), 2],
#  [array([[188, 175, 171, ..., 184, 188, 189],
#          [170, 181, 194, ..., 191, 181, 186],
#          [184, 188, 170, ..., 196, 226, 230],
#          ...,
#          [181, 162, 152, ...,  52,  59,  61],
#          [147, 142, 141, ...,  42,  53,  59],
#          [157, 154, 154, ...,  42,  49,  54]], dtype=uint8), 2],
#  [array([[ 90,  95, 104, ...,  51,  47,  35],
#          [ 82,  89,  95, ...,  47,  44,  50],
#          [100, 102,  94, ...,  41,  43,  89],
#          ...,
#          [ 58,  67,  55, ...,  53,  17,  17],
#          [ 69,  70,  71, ...,  63,  59,  67],
#          [ 64,  65,  67, ...,  30,  50,  57]], dtype=uint8), 2],
#  [array([[177, 177, 177, ..., 173, 174, 174],
#          [177, 177, 177, ..., 170, 173, 173],
#          [177, 177, 177, ..., 168, 172, 172],
#          ...,
#          [177, 176, 173, ...,  18,  24, 125],
#          [160, 161, 162, ...,  11,  83, 162],
#          [169, 172, 176, ...,  16, 108, 182]], dtype=uint8), 2],
#  [array([[176, 176, 175, ..., 132, 157, 156],
#          [175, 174, 174, ..., 110,  95, 115],
#          [174, 173, 173, ...,  25,  63,  88],
#          ...,
#          [199, 200, 200, ..., 189, 187, 187],
#          [197, 196, 194, ..., 188, 186, 186],
#          [192, 191, 190, ..., 188, 186, 186]], dtype=uint8), 2],
#  [array([[180, 183, 184, ..., 181, 179, 179],
#          [194, 192, 189, ..., 181, 179, 179],
#          [190, 189, 190, ..., 180, 179, 179],
#          ...,
#          [  0,  28,  52, ..., 140, 155, 155],
#          [  8,  19, 145, ..., 166, 151, 151],
#          [ 19,  66, 193, ..., 163, 161, 161]], dtype=uint8), 2],
#  [array([[ 38,  48, 148, ...,  87, 195, 216],
#          [ 67,  35,  90, ..., 209, 234, 236],
#          [107,  26,  48, ..., 219, 233, 227],
#          ...,
#          [ 88,  87,  87, ...,  71,  70,  79],
#          [ 77,  78,  78, ...,  81,  66,  74],
#          [ 73,  73,  72, ...,  83,  62,  69]], dtype=uint8), 2],
#  [array([[192, 192, 193, ..., 177, 175, 175],
#          [190, 190, 191, ..., 176, 176, 176],
#          [186, 186, 187, ..., 175, 176, 176],
#          ...,
#          [201, 199, 195, ..., 251, 238, 238],
#          [171, 189, 190, ..., 210, 224, 224],
#          [167, 187, 191, ..., 201, 197, 197]], dtype=uint8), 2],
#  [array([[174, 174, 174, ..., 197, 202, 200],
#          [174, 174, 174, ..., 197, 202, 200],
#          [174, 174, 174, ..., 198, 202, 200],
#          ...,
#          [206, 206, 205, ..., 192, 193, 199],
#          [196, 196, 196, ..., 200, 194, 194],
#          [196, 196, 195, ..., 198, 185, 185]], dtype=uint8), 2],
#  [array([[197, 197, 196, ..., 179, 189, 189],
#          [213, 210, 206, ..., 193, 188, 188],
#          [248, 241, 228, ..., 196, 187, 187],
#          ...,
#          [175, 177, 180, ..., 133, 164, 176],
#          [178, 180, 183, ..., 146, 139, 141],
#          [178, 180, 183, ..., 156, 155, 156]], dtype=uint8), 2],
#  [array([[171, 171, 171, ..., 179, 178, 178],
#          [171, 171, 171, ..., 179, 178, 178],
#          [171, 171, 171, ..., 179, 178, 178],
#          ...,
#          [162, 162, 162, ...,  55, 178, 178],
#          [165, 164, 164, ...,  69,  87, 182],
#          [169, 169, 168, ...,  44,  87, 182]], dtype=uint8), 2],
#  [array([[230, 229, 227, ..., 228, 229, 229],
#          [221, 221, 222, ..., 224, 230, 230],
#          [218, 220, 222, ..., 234, 230, 230],
#          ...,
#          [ 70,  74,  72, ...,  32,  51,  84],
#          [ 72,  77,  73, ...,  26,  70,  74],
#          [ 72,  77,  73, ...,  17,  72,  75]], dtype=uint8), 2],
#  [array([[177, 178, 179, ..., 170, 173, 173],
#          [177, 178, 179, ..., 179, 180, 180],
#          [177, 178, 179, ..., 175, 177, 177],
#          ...,
#          [179, 180, 180, ..., 184, 175, 174],
#          [179, 180, 180, ..., 192, 189, 190],
#          [179, 180, 180, ..., 194, 191, 192]], dtype=uint8), 2],
#  [array([[130, 114, 113, ..., 170, 174, 174],
#          [ 43,  49,  54, ..., 189, 182, 182],
#          [ 82,  89,  84, ..., 161, 175, 175],
#          ...,
#          [ 70,  72,  76, ...,  83,  80,  80],
#          [ 71,  74,  73, ...,  82,  82,  82],
#          [ 71,  74,  73, ...,  82,  82,  82]], dtype=uint8), 2],
#  [array([[168, 174, 179, ...,  29,  33,  19],
#          [166, 171, 176, ...,  29,  28,  18],
#          [178, 177, 178, ...,  29,  21,  20],
#          ...,
#          [ 40,  35,  36, ..., 238, 229, 223],
#          [ 54,  39,  31, ..., 229, 240, 240],
#          [ 72,  54,  40, ..., 234, 230, 230]], dtype=uint8), 2],
#  [array([[177, 176, 176, ..., 200, 203, 203],
#          [177, 176, 176, ..., 189, 203, 203],
#          [177, 176, 176, ..., 177, 203, 203],
#          ...,
#          [184, 184, 184, ..., 191, 191, 191],
#          [182, 182, 182, ..., 187, 188, 188],
#          [180, 180, 180, ..., 187, 188, 188]], dtype=uint8), 2],
#  [array([[206, 196, 202, ..., 181, 180, 183],
#          [203, 196, 203, ..., 199, 178, 181],
#          [199, 197, 204, ..., 163, 185, 185],
#          ...,
#          [204, 203, 202, ..., 170, 180, 185],
#          [196, 193, 192, ..., 175, 175, 181],
#          [201, 198, 195, ..., 175, 173, 178]], dtype=uint8), 2],
#  [array([[ 77,  66,  40, ..., 110, 196, 204],
#          [ 74,  71,  51, ...,  74, 148, 158],
#          [ 73,  76,  64, ...,  83,  79,  85],
#          ...,
#          [162, 163, 165, ..., 239, 246, 248],
#          [171, 182, 186, ..., 245, 244, 244],
#          [207, 221, 226, ..., 245, 244, 244]], dtype=uint8), 2],
#  [array([[176, 156, 164, ..., 184, 190, 190],
#          [173, 155, 162, ..., 205, 197, 197],
#          [173, 160, 165, ..., 191, 195, 195],
#          ...,
#          [177, 174, 175, ..., 191, 190, 190],
#          [181, 181, 182, ..., 190, 189, 189],
#          [185, 185, 186, ..., 184, 189, 189]], dtype=uint8), 2],
#  [array([[178, 178, 177, ..., 195, 201, 201],
#          [178, 178, 177, ..., 200, 207, 207],
#          [178, 178, 177, ..., 206, 208, 208],
#          ...,
#          [171, 165, 163, ..., 178, 184, 184],
#          [171, 166, 176, ..., 185, 189, 189],
#          [167, 165, 178, ..., 187, 189, 189]], dtype=uint8), 2],
#  [array([[202, 204, 200, ..., 177, 177, 177],
#          [202, 205, 201, ..., 177, 177, 177],
#          [203, 206, 202, ..., 177, 177, 177],
#          ...,
#          [223, 218, 237, ..., 241, 241, 241],
#          [192, 215, 221, ..., 230, 229, 229],
#          [211, 225, 221, ..., 220, 221, 221]], dtype=uint8), 2],
#  [array([[123, 146, 174, ..., 203, 204, 204],
#          [192, 159, 130, ..., 203, 204, 204],
#          [168, 184, 188, ..., 204, 204, 204],
#          ...,
#          [181, 178, 178, ..., 237, 238, 237],
#          [181, 181, 180, ..., 234, 228, 241],
#          [181, 181, 180, ..., 188, 219, 233]], dtype=uint8), 2],
#  [array([[207, 112,  47, ..., 176, 182, 181],
#          [202, 169,  59, ..., 179, 173, 173],
#          [197, 202, 136, ..., 178, 161, 162],
#          ...,
#          [177, 178, 178, ..., 175, 188, 188],
#          [171, 171, 171, ..., 172, 180, 186],
#          [171, 171, 171, ..., 172, 178, 183]], dtype=uint8), 2],
#  [array([[199, 188, 170, ..., 177, 178, 178],
#          [201, 202, 202, ..., 177, 178, 178],
#          [190, 193, 197, ..., 176, 178, 178],
#          ...,
#          [200, 197, 201, ..., 160, 189, 194],
#          [201, 201, 201, ..., 170, 161, 167],
#          [201, 201, 201, ..., 165, 166, 171]], dtype=uint8), 2],
#  [array([[ 46,  54,  50, ...,  70,  55,  43],
#          [ 36,  53,  44, ...,  69, 144, 131],
#          [ 49,  46,  34, ...,  77, 198, 202],
#          ...,
#          [229, 230, 229, ..., 105, 108, 105],
#          [222, 205, 202, ..., 103, 103, 105],
#          [197, 193, 208, ..., 106, 103, 105]], dtype=uint8), 2],
#  [array([[196, 196, 191, ..., 188, 179, 182],
#          [203, 205, 208, ..., 180, 184, 186],
#          [208, 205, 199, ..., 189, 187, 189],
#          ...,
#          [200, 202, 203, ..., 186, 183, 183],
#          [202, 204, 204, ..., 184, 181, 181],
#          [202, 204, 204, ..., 184, 181, 181]], dtype=uint8), 2],
#  [array([[216, 250, 247, ..., 171, 184, 172],
#          [196, 245, 249, ..., 176, 169, 169],
#          [158, 231, 251, ..., 167, 146, 158],
#          ...,
#          [143, 112,  76, ...,  72,  75,  76],
#          [ 71,  59,  81, ...,  68,  73,  75],
#          [ 65, 124, 177, ...,  66,  73,  75]], dtype=uint8), 2],
#  [array([[144, 151, 146, ..., 229, 236, 208],
#          [154, 143, 141, ..., 217, 237, 208],
#          [125, 118, 132, ..., 225, 232, 203],
#          ...,
#          [ 88,  92,  79, ...,  78,  80,  80],
#          [ 74,  71,  77, ...,  94,  68,  68],
#          [ 74,  71,  77, ...,  83,  96,  96]], dtype=uint8), 2],
#  [array([[169, 160, 174, ...,  75, 136, 174],
#          [133, 140, 164, ...,  94, 163, 185],
#          [178, 159, 147, ..., 128, 187, 191],
#          ...,
#          [193, 187, 186, ..., 196, 202, 210],
#          [189, 190, 189, ..., 195, 196, 196],
#          [189, 190, 189, ..., 191, 195, 195]], dtype=uint8), 2],
#  ...]

# %%
import random
from keras.initializers import glorot_uniform
from keras.utils import CustomObjectScope
random.shuffle(trainingdata())
X1 = []
y1 = []
for features,label in trainingdata():
    X1.append(features)
    y1.append(label)
x_train=X1[:1500]
x_test=X1[:472]
x_train1=np.array(x_train).reshape(-1,50,50,1)
x3=x_train1/255.0
y2=np.array(y1)
y_train=y2[:1500]
y_test=y2[:472]
ip=np.array(x3)
model1=tf.keras.models.Sequential([ tf.keras.layers.Conv2D(64,(3,3),activation='relu',
                                                           input_shape=(ip.shape[1:])),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(64,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(128,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(128,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(256,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(256,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=2,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=1,padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(), tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(2,2),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(1024,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Dropout(0.2),
                                   tf.keras.layers.DepthwiseConv2D(3,strides=(1,1),padding='same'),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(),
                                   tf.keras.layers.Conv2D(512,(1,1)),
                                   tf.keras.layers.BatchNormalization(),
                                   tf.keras.layers.ReLU(), 
                                   tf.keras.layers.GlobalAvgPool2D(), 
                                   tf.keras.layers.Dense(5,activation='softmax')])
model1.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
target=np.array(y_train)
model1.fit(ip,target,epochs=20)
# Out:
# Train on 1500 samples
# Epoch 1/20
# 1500/1500 [==============================] - 143s 95ms/sample - loss: 1.4988 - accuracy: 0.3940
# Epoch 2/20
# 1500/1500 [==============================] - 104s 69ms/sample - loss: 1.1571 - accuracy: 0.5147
# Epoch 3/20
# 1500/1500 [==============================] - 109s 73ms/sample - loss: 0.9774 - accuracy: 0.6220
# Epoch 4/20
# 1500/1500 [==============================] - 106s 71ms/sample - loss: 0.7936 - accuracy: 0.6693
# Epoch 5/20
# 1500/1500 [==============================] - 102s 68ms/sample - loss: 0.7091 - accuracy: 0.7293
# Epoch 6/20
# 1500/1500 [==============================] - 106s 71ms/sample - loss: 0.6466 - accuracy: 0.7587
# Epoch 7/20
# 1500/1500 [==============================] - 116s 78ms/sample - loss: 0.5883 - accuracy: 0.7860
# Epoch 8/20
# 1500/1500 [==============================] - 108s 72ms/sample - loss: 0.5216 - accuracy: 0.7987
# Epoch 9/20
# 1500/1500 [==============================] - 104s 70ms/sample - loss: 0.4335 - accuracy: 0.8473
# Epoch 10/20
# 1500/1500 [==============================] - 108s 72ms/sample - loss: 0.3642 - accuracy: 0.8627
# Epoch 11/20
# 1500/1500 [==============================] - 109s 73ms/sample - loss: 0.2661 - accuracy: 0.9133
# Epoch 12/20
# 1500/1500 [==============================] - 112s 75ms/sample - loss: 0.2032 - accuracy: 0.9340
# Epoch 13/20
# 1500/1500 [==============================] - 109s 72ms/sample - loss: 0.1678 - accuracy: 0.9513
# Epoch 14/20
# 1500/1500 [==============================] - 117s 78ms/sample - loss: 0.1413 - accuracy: 0.9560
# Epoch 15/20
# 1500/1500 [==============================] - 114s 76ms/sample - loss: 0.1393 - accuracy: 0.9507
# Epoch 16/20
# 1500/1500 [==============================] - 113s 76ms/sample - loss: 0.0922 - accuracy: 0.9653
# Epoch 17/20
# 1500/1500 [==============================] - 119s 79ms/sample - loss: 0.1268 - accuracy: 0.9593
# Epoch 18/20
# 1500/1500 [==============================] - 121s 81ms/sample - loss: 0.0837 - accuracy: 0.9787
# Epoch 19/20
# 1500/1500 [==============================] - 113s 75ms/sample - loss: 0.0824 - accuracy: 0.9740
# Epoch 20/20
# 1500/1500 [==============================] - 127s 84ms/sample - loss: 0.0921 - accuracy: 0.9673

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# re_lu (ReLU)                 (None, 48, 48, 64)        0
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 64)        0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 24, 24, 64)        640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       8320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 24, 24, 128)       0
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 24, 24, 128)       1280
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       16512
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 24, 24, 128)       0
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 12, 12, 128)       1280
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 256)       33024
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 256)       0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 12, 12, 256)       2560
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       65792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 12, 12, 256)       1024
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 256)       0
# _________________________________________________________________
# depthwise_conv2d_5 (Depthwis (None, 6, 6, 256)         2560
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 512)         131584
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 6, 6, 512)         0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 6, 6, 512)         5120
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         262656
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 6, 6, 512)         0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 3, 3, 512)         5120
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 512)         262656
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# depthwise_conv2d_8 (Depthwis (None, 3, 3, 512)         5120
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 512)         262656
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 3, 3, 512)         0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_10 (Depthwi (None, 2, 2, 512)         5120
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         262656
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 2, 2, 512)         0
# _________________________________________________________________
# depthwise_conv2d_11 (Depthwi (None, 1, 1, 512)         5120
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 1024)        525312
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# depthwise_conv2d_12 (Depthwi (None, 1, 1, 1024)        10240
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 512)         524800
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 2565
# =================================================================
# Total params: 2,717,893
# Trainable params: 2,696,901
# Non-trainable params: 20,992
# _________________________________________________________________

# %%
model1.save("mobilenet.h5")

# %%
import tensorflow as tf

# %%
#quantization
converter = tf.compat.v1.lite.TocoConverter.from_keras_model_file("mobilenet.h5")
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_quant_model = converter.convert()
open('pred1.tflite','wb').write(tflite_quant_model)
# Out:
# WARNING:tensorflow:From <ipython-input-17-f52141a94978>:1: TocoConverter.from_keras_model_file (from tensorflow.lite.python.lite) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `lite.TFLiteConverter.from_keras_model_file` instead.
# 2727784

# %%
import tkinter as tk
from tkinter import filedialog
filename = filedialog.askopenfilename()
im_arr=cv2.imread(filename)
img_array = cv2.imread(filename ,cv2.IMREAD_GRAYSCALE)  
new_array = cv2.resize(img_array, (50,50))
xtest=new_array/255.0
g=np.array(xtest).reshape(1,50,50,1)
prob=model1.predict(g)
#y_ttt=str(input('label'))
#accuracy1=accuracy_score(prob,)
number_to_class=['pavan','balaji','krishna','shakeel','abhilash']
sorti=np.argmax(prob)
print('most likely class:',number_to_class[sorti])
#print(sorti/100)
print(prob)
#print(accuracy1)
# Out:
# most likely class: krishna
# [[2.1876821e-02 1.6087079e-01 8.1722552e-01 2.2924518e-05 3.9478941e-06]]
